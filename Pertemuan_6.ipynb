# %% [markdown]
# <a href="https://colab.research.google.com/github/harisradja/Praktikum-Struktur-Data/blob/main/Pertemuan_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: None

# %% [markdown]
# Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Insertion Sort

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Merge Sort

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Tugas rombel 4

# %%
def quick_sort_recommendation(arr):
    # Jika daftar kosong atau berisi satu elemen, data sudah terurut
    if len(arr) <= 1:
        return arr

    # Memilih elemen tengah sebagai pivot
    pivot = arr[len(arr) // 2]

    # Logika Descending:
    # 'left' berisi elemen yang ratingnya LEBIH TINGGI dari pivot
    # 'right' berisi elemen yang ratingnya LEBIH RENDAH dari pivot
    left = [x for x in arr if x['rating'] > pivot['rating']]
    middle = [x for x in arr if x['rating'] == pivot['rating']]
    right = [x for x in arr if x['rating'] < pivot['rating']]

    # Rekursi dan penggabungan hasil
    return quick_sort_recommendation(left) + middle + quick_sort_recommendation(right)

# Data lagu contoh (Nama Lagu dan Rating dari 1-10)
daftar_lagu = [
    {"judul": "Last Burger From You", "rating": 9.5},
    {"judul": "Lucid Dreams", "rating": 8.8},
    {"judul": "Nuts", "rating": 9.2},
    {"judul": "0312", "rating": 8.5},
    {"judul": "Pudar", "rating": 9.0}
]

print("--- Daftar Lagu Sebelum Diurutkan ---")
for lagu in daftar_lagu:
    print(f"{lagu['judul']} - Rating: {lagu['rating']}")

# Menjalankan proses sorting
rekomendasi = quick_sort_recommendation(daftar_lagu)

print("\n--- Rekomendasi Lagu (Rating Tertinggi) ---")
for i, lagu in enumerate(rekomendasi, 1):
    print(f"{i}. {lagu['judul']} (Rating: {lagu['rating']})")
# Out:
# --- Daftar Lagu Sebelum Diurutkan ---
# Last Burger From You - Rating: 9.5
# Lucid Dreams - Rating: 8.8
# Nuts - Rating: 9.2
# 0312 - Rating: 8.5
# Pudar - Rating: 9.0
#
# --- Rekomendasi Lagu (Rating Tertinggi) ---
# 1. Last Burger From You (Rating: 9.5)
# 2. Nuts (Rating: 9.2)
# 3. Pudar (Rating: 9.0)
# 4. Lucid Dreams (Rating: 8.8)
# 5. 0312 (Rating: 8.5)
